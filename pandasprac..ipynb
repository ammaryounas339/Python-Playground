# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset("titanic")
df_1 = df.sample(frac  = 0.5)
df_1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 730         1       1  female  29.0      0      0  211.3375        S  First
# 572         1       1    male  36.0      0      0   26.3875        S  First
# 403         0       3    male  28.0      1      0   15.8500        S  Third
# 271         1       3    male  25.0      0      0    0.0000        S  Third
# 365         0       3    male  30.0      0      0    7.2500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 730  woman       False    B  Southampton   yes   True
# 572    man        True    E  Southampton   yes   True
# 403    man        True  NaN  Southampton    no  False
# 271    man        True  NaN  Southampton   yes   True
# 365    man        True  NaN  Southampton    no   True

# %%
df_2 = df.drop(df_1.index)
df_2.head()
df_joined = df_1.append(df_2)
df_joined.shape
# Out:
# C:\Users\Ammar Younas\AppData\Local\Temp\ipykernel_7944\2267589763.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_joined = df_1.append(df_2)
# (891, 15)

# %%
df[df.sex == "female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df.embark_town == "Southampton") & (df.sex == "female")].shape
# Out:
# (203, 15)

# %%
df.age.value_counts().nlargest(2)
# Out:
# 24.0    30
# 22.0    27
# Name: age, dtype: int64

# %%
counts = df.embark_town.value_counts()
print(counts.nlargest(3))
print(counts[counts > 150])
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64
# Southampton    644
# Cherbourg      168
# Name: embark_town, dtype: int64

# %%
df[df.embark_town.isin(counts[counts > 150].index)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#create a 3*2 dataframe with name and location column , fill it with random values having real names and cities

import numpy as np
df = pd.DataFrame({'name':["Muhammad Ammar","Ahmed Raza"],
                   "location" :["Islamabad,Paksitan","hamburg,germany"]})

# %%
df
# Out:
#              name            location
# 0  Muhammad Ammar  Islamabad,Paksitan
# 1      Ahmed Raza     hamburg,germany

# %%
df[["first_name","last_name"]] = df.name.str.split(" ",expand = True)
df
# Out:
#              name            location first_name last_name
# 0  Muhammad Ammar  Islamabad,Paksitan   Muhammad     Ammar
# 1      Ahmed Raza     hamburg,germany      Ahmed      Raza

# %%
df[["city","country"]] = df.location.str.split(",",expand = True)

# %%
df
# Out:
#              name            location first_name last_name       city  \
# 0  Muhammad Ammar  Islamabad,Paksitan   Muhammad     Ammar  Islamabad
# 1      Ahmed Raza     hamburg,germany      Ahmed      Raza    hamburg
#
#     country
# 0  Paksitan
# 1   germany

# %%
df = df[["first_name","last_name","country","city"]]
df
# Out:
#   first_name last_name   country       city
# 0   Muhammad     Ammar  Paksitan  Islamabad
# 1      Ahmed      Raza   germany    hamburg

# %%
df = sns.load_dataset("titanic")
df.head
# Out:
# <bound method NDFrame.head of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.groupby("who").count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
df.describe()
#df.describe().loc[["min","mean","75%"]]
df.describe().loc[:,'pclass' : 'fare']
# Out:
#            pclass         age       sibsp       parch        fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
# convert continous to categorical
pd.cut(df.age,bins = [0,18,25,99],labels=["child","young_adult","adult"])
# Out:
# 0      young_adult
# 1            adult
# 2            adult
# 3            adult
# 4            adult
#           ...
# 886          adult
# 887    young_adult
# 888            NaN
# 889          adult
# 890          adult
# Name: age, Length: 891, dtype: category
# Categories (3, object): ['child' < 'young_adult' < 'adult']

# %%
# convert continous to categorical
df.sex.map({"male":0,
            "female":1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: sex, Length: 891, dtype: int64

# %%
# transpose a dataframe
import numpy as np

df = pd.DataFrame(np.random.rand(200,26),columns = list("abcdefghijklmnopqrstuvwxyz"))
df.head
# Out:
# <bound method NDFrame.head of             a         b         c         d         e         f         g  \
# 0    0.248408  0.860890  0.026916  0.966562  0.880612  0.900065  0.332809
# 1    0.821422  0.096658  0.505839  0.958518  0.928925  0.842333  0.169938
# 2    0.858283  0.681722  0.125315  0.510821  0.373853  0.317786  0.220095
# 3    0.714346  0.526716  0.254826  0.051354  0.899153  0.734451  0.499202
# 4    0.265197  0.128524  0.684700  0.830545  0.371525  0.134631  0.026485
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.160138  0.534086  0.740304  0.821292  0.270807  0.874451  0.533882
# 196  0.219725  0.514766  0.714880  0.136035  0.836638  0.854124  0.706360
# 197  0.392666  0.352867  0.467573  0.977358  0.845550  0.822554  0.886777
# 198  0.102167  0.474560  0.688505  0.875286  0.455567  0.571790  0.297780
# 199  0.739045  0.387899  0.114916  0.504354  0.314823  0.907382  0.170359
#
# ...

# %%
df.head().T
# Out:
#           0         1         2         3         4
# a  0.248408  0.821422  0.858283  0.714346  0.265197
# b  0.860890  0.096658  0.681722  0.526716  0.128524
# c  0.026916  0.505839  0.125315  0.254826  0.684700
# d  0.966562  0.958518  0.510821  0.051354  0.830545
# e  0.880612  0.928925  0.373853  0.899153  0.371525
# f  0.900065  0.842333  0.317786  0.734451  0.134631
# g  0.332809  0.169938  0.220095  0.499202  0.026485
# h  0.925816  0.773532  0.040847  0.911385  0.271034
# i  0.612077  0.230419  0.680171  0.755124  0.267492
# j  0.427853  0.365879  0.538607  0.422238  0.964464
# k  0.174996  0.832806  0.382370  0.318112  0.216539
# l  0.764421  0.719237  0.293335  0.891390  0.757485
# m  0.980798  0.366277  0.908782  0.020267  0.297594
# n  0.687202  0.567253  0.341302  0.940858  0.308196
# o  0.868471  0.640165  0.377034  0.242945  0.355329
# p  0.935435  0.103566  0.951514  0.717491  0.379393
# q  0.046601  0.813661  0.338047  0.017089  0.042502
# ...

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset("titanic")  
df.groupby("sex").describe().T
# Out:
# sex                 female        male
# survived count  314.000000  577.000000
#          mean     0.742038    0.188908
#          std      0.438211    0.391775
#          min      0.000000    0.000000
#          25%      0.000000    0.000000
#          50%      1.000000    0.000000
#          75%      1.000000    0.000000
#          max      1.000000    1.000000
# pclass   count  314.000000  577.000000
#          mean     2.159236    2.389948
#          std      0.857290    0.813580
#          min      1.000000    1.000000
#          25%      1.000000    2.000000
#          50%      2.000000    3.000000
#          75%      3.000000    3.000000
#          max      3.000000    3.000000
# age      count  261.000000  453.000000
#          mean    27.915709   30.726645
#          std     14.110146   14.678201
#          min      0.750000    0.420000
#          25%     18.000000   21.000000
#          50%     27.000000   29.000000
#          75%     37.000000   39.000000
# ...

# %%
df.sort_values("pclass",ascending=False)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[df["age"]<5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
import matplotlib.pyplot as plt
df = sns.load_dataset("titanic")
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.survived.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x = "survived",hue = "sex",data = df)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
plt.scatter(data=df,x = "age",y="fare")

# %%
sns.scatterplot(data=df,x = "age",y="fare",hue = "pclass")
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.dtypes
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].max()
df['age'].fillna(df["age"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["embarked"].fillna(df["embarked"].mode()[0],inplace=True)
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 import seaborn as sns
# ----> 2 df = sns.load_dataset("Cutlery")
#       3 df.head()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\seaborn\utils.py:595, in load_dataset(name, cache, data_home, **kws)
#     593 if not os.path.exists(cache_path):
#     594     if name not in get_dataset_names():
# --> 595         raise ValueError(f"'{name}' is not one of the example datasets.")
#     596     urlretrieve(url, cache_path)
#     597 full_path = cache_path
#
# ValueError: 'Cutlery' is not one of the example datasets.
